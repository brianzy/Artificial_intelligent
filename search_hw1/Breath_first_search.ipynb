# %%
import time
import random
def read_words_file():
    """
    read words from dictionary,
    return words list
    """
    with open ("Words.txt", "r") as myfile:
        dicts=myfile.read()
        dicts = dicts.split()
    return dicts

# %%
def random_pick(dicts):
    """
    randomly pick two words with same 
    length in the dicts
    """
    start=random.choice(dicts)
    random.shuffle(dicts)
    for i in dicts:
        if len(i)== len(start):
            end=i
            return start, end

# %%
class word_obj(object):
    '''
    create word object to contain score, string 
    and parent
    '''
    def __init__(self, string, score=0, parent=""):
        self.string = string
        self.score = score
        self.parent = parent

# %%
def find_neighbours(word,wordList):
    """
    check letters in word from a to z 
    generate different words which only one
    letter different from orignal words
    compare with dicts and word itsself,
    if we can find change in dicts then
    append the result to a list6
    """
    word=''.join(word)
    neighbours= list()    
    for ind in range(len(word)):
        temp = word[ind]
        for alphbet in [chr(x) for x in range(ord('a'), ord('z')+1)]:
            if alphbet != temp:
                new_word = word[:ind]+ alphbet +word[ind+1:]
                if new_word != word and new_word in wordList:
                    neighbours.append(new_word)
                    wordList.remove(new_word)
                    
                    
    #print("word:",word,"neighbours:",neighbours)                
    return neighbours

# %%
def find_path(startWord,visited,parent,string):
    """
    after find the endword, use this function 
    trace back through the parent attribute to 
    the startword. Eventually return a path list
    contain all the word in the path.
    """
    path=[string]
    for ind in range(len(visited)):
            if parent == visited[ind].string:
                path.insert(0,visited[ind].string)
    while True:
        for ind2 in range(len(visited)):
            if path[0] == visited[ind2].string:
                path.insert(0,visited[ind2].parent)
                continue

            if path[0]== startWord:
                return path

# %%
def bfs(startWord, endWord, wordList):
    '''
    breath first search
    use queue to search
    '''
    result = 0
    visited =[]
    temp=[]
    fringe = [word_obj(startWord)]
    wordList.remove(startWord)
    x=[]
    for i in find_neighbours(startWord,wordList):
        x.append(word_obj(i,0,startWord))
    fringe.extend(x)
    while len(fringe)>=0:
        for obj in fringe:
            temp=fringe.pop(0) 
            visited.append(temp)
            result +=1
            temp1=find_neighbours(temp.string,wordList)
            temp3=[]
            for word in temp1:
                temp2=word_obj(word,0,temp.string) 
                temp3.append(temp2)
            fringe.extend(temp3)

            for ind in range(len(fringe)):
                if endWord == fringe[ind].string:
                    return print("steps: ", result,"path:", find_path(startWord,visited,fringe[ind].parent,fringe[ind].string) )
                
        if len(fringe)==0:
            return "no solution!"

# %%
import numpy as np
def random100():
    """
    100 times randomly selection two word from
    dictionary and return average time.
    """    
    time1=0
    for i in range(100):
        dicts= read_words_file()
        beginWord, endWord = random_pick(dicts)
        print("begin word:", beginWord, "end word:",endWord)
        starttime=time.time()
        print(bfs(beginWord, endWord, dicts))
        endtime=time.time()
        time_taken = endtime - starttime
        time1=time1+time_taken
    avg_time=time1/100
    return print("The 100 random breath first search average time is  ",avg_time)


random100()
# Out:
# begin word: abbot end word: grant
# no solution!
# None
# begin word: sarcasm end word: benison
# no solution!
# None
# begin word: evacuate end word: bludgeon
# no solution!
# None
# begin word: plaid end word: lymph
# no solution!
# None
# begin word: pigpen end word: toddle
# no solution!
# None
# begin word: bake end word: quip
# steps:  1467 path: ['bake', 'sake', 'sane', 'sand', 'said', 'skid', 'skit', 'suit', 'quit', 'quip']
# None
# begin word: chicken end word: gelding
# no solution!
# None
# begin word: thralldom end word: boatswain
# no solution!
# None
# begin word: vacate end word: poster
# no solution!
# None
# begin word: becloud end word: prebend
# no solution!
# None
# begin word: avoid end word: stood
# no solution!
# None
# begin word: distance end word: saucepan
# no solution!
# None
# begin word: camber end word: locale
# no solution!
# None
# begin word: fingerboard end word: polytechnic
# no solution!
# None
# begin word: mule end word: food
# steps:  352 path: ['mule', 'mole', 'mold', 'fold', 'food']
# None
# begin word: taunt end word: osier
# no solution!
# None
# begin word: antiquity end word: germanium
# no solution!
# None
# begin word: brickbat end word: decrepit
# no solution!
# None
# begin word: parcel end word: baobab
# no solution!
# None
# begin word: stupefy end word: postern
# no solution!
# None
# begin word: dauphin end word: neither
# no solution!
# None
# begin word: twin end word: maid
# steps:  141 path: ['twin', 'thin', 'shin', 'skin', 'skid', 'said', 'maid']
# None
# begin word: cape end word: clog
# steps:  1040 path: ['cape', 'case', 'cast', 'cost', 'coot', 'clot', 'clog']
# None
# begin word: keg end word: cam
# steps:  198 path: ['keg', 'beg', 'bag', 'hag', 'ham', 'cam']
# None
# begin word: bookie end word: saloon
# no solution!
# None
# begin word: vague end word: arbor
# no solution!
# None
# begin word: paddy end word: hazel
# no solution!
# None
# begin word: purge end word: spade
# steps:  609 path: ['purge', 'surge', 'serge', 'verge', 'verse', 'terse', 'tease', 'cease', 'chase', 'chasm', 'charm', 'chard', 'shard', 'share', 'spare', 'spade']
# None
# begin word: vitals end word: chatty
# no solution!
# None
# begin word: unread end word: rakish
# no solution!
# None
# begin word: control end word: mermaid
# no solution!
# None
# begin word: debar end word: tumor
# no solution!
# None
# begin word: asylum end word: barrow
# no solution!
# None
# begin word: sacristan end word: stockpile
# no solution!
# None
# begin word: circulate end word: protector
# no solution!
# None
# begin word: anodyne end word: tremble
# no solution!
# None
# begin word: anteroom end word: tinplate
# no solution!
# None
# begin word: grievance end word: acquiesce
# no solution!
# None
# begin word: arteriosclerosis end word: decentralization
# no solution!
# None
# begin word: vaccine end word: plumage
# no solution!
# None
# begin word: snooze end word: mottle
# no solution!
# None
# begin word: forsooth end word: laxative
# no solution!
# None
# begin word: extinguish end word: unfamiliar
# no solution!
# None
# begin word: bet end word: fur
# steps:  101 path: ['bet', 'but', 'bur', 'fur']
# None
# begin word: lectern end word: freshen
# no solution!
# None
# begin word: bestiality end word: posthumous
# no solution!
# None
# begin word: ism end word: law
# no solution!
# None
# begin word: content end word: through
# no solution!
# None
# begin word: baronage end word: dressing
# no solution!
# None
# begin word: infection end word: esophagus
# no solution!
# None
# begin word: consequent end word: omniscient
# no solution!
# None
# begin word: wreath end word: mussel
# no solution!
# None
# begin word: radish end word: senate
# no solution!
# None
# begin word: abide end word: magic
# no solution!
# None
# begin word: aport end word: gawky
# no solution!
# None
# begin word: prescribe end word: outwardly
# no solution!
# None
# begin word: workbook end word: barbaric
# no solution!
# None
# begin word: obsequy end word: coating
# no solution!
# None
# begin word: proceeds end word: interval
# no solution!
# None
# begin word: math end word: farm
# steps:  137 path: ['math', 'mate', 'fate', 'fare', 'farm']
# None
# begin word: racecourse end word: stigmatize
# no solution!
# None
# begin word: stigma end word: jailer
# no solution!
# None
# begin word: tyrannize end word: victimize
# no solution!
# None
# begin word: ibex end word: dike
# no solution!
# None
# begin word: expenditure end word: machination
# no solution!
# None
# begin word: evacuee end word: rivulet
# no solution!
# None
# begin word: quotient end word: tailcoat
# no solution!
# None
# begin word: urinary end word: vitiate
# no solution!
# None
# begin word: federalist end word: virtuosity
# no solution!
# None
# begin word: metro end word: stoat
# no solution!
# None
# begin word: density end word: pungent
# no solution!
# None
# begin word: ineffable end word: arabesque
# no solution!
# None
# begin word: coquette end word: leverage
# no solution!
# None
# begin word: pimp end word: bade
# steps:  229 path: ['pimp', 'limp', 'lamp', 'lame', 'fame', 'fade', 'bade']
# None
# begin word: diary end word: ruddy
# no solution!
# None
# begin word: appertain end word: professor
# no solution!
# None
# begin word: plutocracy end word: reportedly
# no solution!
# None
# begin word: toward end word: shrike
# no solution!
# None
# begin word: subconscious end word: headquarters
# no solution!
# None
# begin word: station end word: octagon
# no solution!
# None
# begin word: coverlet end word: outboard
# no solution!
# None
# begin word: incumber end word: serenade
# no solution!
# None
# begin word: gaucherie end word: reservist
# no solution!
# None
# begin word: counterpoint end word: insufferable
# no solution!
# None
# begin word: immune end word: behalf
# no solution!
# None
# begin word: buzzer end word: influx
# no solution!
# None
# begin word: calculation end word: calorimeter
# no solution!
# None
# begin word: statement end word: prevalent
# no solution!
# None
# begin word: tradesman end word: deformity
# no solution!
# None
# begin word: debouch end word: alfalfa
# no solution!
# None
# begin word: subordinate end word: assassinate
# no solution!
# None
# begin word: caddie end word: lagoon
# no solution!
# None
# begin word: lesson end word: moment
# no solution!
# None
# begin word: panelist end word: cogitate
# no solution!
# None
# begin word: bishopric end word: addressee
# no solution!
# None
# begin word: clear end word: stamp
# steps:  552 path: ['clear', 'cleat', 'cheat', 'chert', 'chart', 'chard', 'shard', 'share', 'scare', 'scale', 'scalp', 'scamp', 'stamp']
# None
# begin word: factotum end word: linguist
# no solution!
# None
# begin word: displacement end word: clotheshorse
# no solution!
# None
# begin word: host end word: leaf
# steps:  912 path: ['host', 'lost', 'loot', 'loom', 'loam', 'loaf', 'leaf']
# None
# begin word: enwreathe end word: hamadryad
# no solution!
# None
# The 100 random breath first search average time is   4.250773437023163

# %%
"""
dicts= read_words_file()
beginWord = "stone"
endWord = "winch"
######
#track starttime to run the search
#######
starttime=time.time()
print(bfs(beginWord, endWord, dicts))
######
#track endtime to run the search
#######
endtime=time.time()
time_taken = endtime - starttime
print("Found in time: ")
print(time_taken)
"""
# Out:
# '\ndicts= read_words_file()\nbeginWord = "stone"\nendWord = "winch"\n######\n#track starttime to run the search\n#######\nstarttime=time.time()\nprint(bfs(beginWord, endWord, dicts))\n######\n#track endtime to run the search\n#######\nendtime=time.time()\ntime_taken = endtime - starttime\nprint("Found in time: ")\nprint(time_taken)\n'
